# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_empattrition=pd.read_csv("Employee-Attrition-Dataset.csv")
df_empattrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#shows how many rows and columns
df_empattrition.shape
# Out:
# (1470, 35)

# %%
#shows if there are any null values
df_empattrition.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#shows as the count,mean,standarddeviation,min,max values
df_empattrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Series containing counts of unique values in the specified column

#first row contains the count of employees who did not leave (i.e., Attrition=No) 
#the second row contains the count of employees who did leave (i.e., Attrition=Yes).

attrition_count=pd.DataFrame(df_empattrition["Attrition"].value_counts())
attrition_count
# Out:
#      Attrition
# No        1233
# Yes        237

# %%
# Data Visualization

# %%
plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x2a3cc4f0d90>,
# ...
#  [Text(-1.136781068348268, 0.6306574368426737, 'No'),
#   Text(0.961891673217765, -0.5336332157899547, 'Yes')])

# %%
sns.countplot(x='Attrition' , data=df_empattrition)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x='BusinessTravel', hue='Attrition', data=df_empattrition, palette='prism_r')
plt.show()

# %%
sns.countplot(x='MaritalStatus', hue='Attrition', data=df_empattrition, palette='prism_r')
plt.show()

# %%
sns.countplot(x='Department', hue='Attrition', data=df_empattrition, palette='prism_r')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='JobRole', hue='Attrition', data=df_empattrition, palette='prism_r')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='EducationField', hue='Attrition', data=df_empattrition, palette='prism_r')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='OverTime', hue='Attrition', data=df_empattrition, palette='prism_r')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Age', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='DistanceFromHome', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='JobInvolvement', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='JobLevel', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='JobSatisfaction', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='NumCompaniesWorked', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='PercentSalaryHike', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='PerformanceRating', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='StockOptionLevel', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='TotalWorkingYears', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='WorkLifeBalance', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='YearsAtCompany', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='YearsInCurrentRole', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='YearsSinceLastPromotion', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
sns.countplot(x='YearsWithCurrManager', hue='Attrition', data=df_empattrition, palette='hot')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_empattrition.corr(),annot=True,fmt='.2f',linewidth='0.2')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11020\1396107506.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_empattrition.corr(),annot=True,fmt='.2f',linewidth='0.2')

# %%
Some Observations:

Gender: Male employees quit more than female employees.
Business Travel: The employees who travel rarely are more likely to quit than other employees.
Marital Status: Employees who are single tend to quit their jobs more than the married or divorced.
Department: Research and Development employees don't quit their jobs as much as the other departments.
Job Role: Sales Executives, Laboratory Technicians and Research Scientists are more likely to quit than other employees.
Education Field: Employees from Life Sciences, Medical and Marketing educational background are more likely to stay than other employees of different educational background.
Over Time: Employees who do over time, quit more.

Some Observations:

Young employees aged below 22 yrs, quit their jobs more than the rest.
Employees who travel more than 10 kms to reach office, are more likely to quit.
Environment Satisfaction, Job Satisfaction, Relationship Satisfaction, Job Involvement, Performance Rating, Stock Option Level, Work Life Balance: these features don't really help us in understanding the employees' attrition.
Employees with low Job Level, Monthly Income, Percent Salary Hike, Total Working Years, Years At Company are prone to quitting their jobs.
Employees who have worked in less than 2 comapanies, are more likely to stay.
Employees who have received promotion recently within 2 years, will stay than employees who haven't received any promotion for a long time.
Employees who have spent more than 2 years with their current manager, are more likely to stay.

Some Observations:

Job Level and Monthly Income are highly correlated.
Monthly Income is highly correlated with Total Working Hours.
Job Level and Total Working Hours are highly correlated.
Performance Rating is highly correlated with Percent Salary Hike.
Years in Current Role and Years with Current Manager has high correlation with Years at Company.
